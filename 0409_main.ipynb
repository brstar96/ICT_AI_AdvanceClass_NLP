# %%
from sklearn.metrics import confusion_matrix

# Binomial에 대한 confusion matrix 응용
# 0 : 스팸, 1 : 정상, D : 6
trueY = [1,0,1,1,0,1]
predY = [0,0,1,1,0,1]

P:(2/3)*(3/3)
R:()
    
result = confusion_matrix(trueY, predY) # scikit learn의 confusion matrix는 transpose되어있음.

# %% [markdown]
# (이미지 속 P와 R은 잘못 계산된 값)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# * Precision : 모델이 예측한 정답 중 진짜 정답의 비율
# * Recall : 진짜 정답 중 모델이 찾은 정답의 비율

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result = result.transpose()
result
# Out:
# array([[2, 1],
#        [0, 3]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(trueY, predY))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.75      0.86         4
#
#    micro avg       0.83      0.83      0.83         6
#    macro avg       0.83      0.88      0.83         6
# weighted avg       0.89      0.83      0.84         6

# %%
for i in range(result.shape[0]):
    print("Precision: {0}".format(result[i, i] / result[i].sum()))
    print("Recall: {0}".format(result[i, i] / result[:, i].sum()))
# Out:
# Precision: 0.6666666666666666
# Recall: 1.0
# Precision: 1.0
# Recall: 0.75

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# classification_report를 직접 구현해 보기(class = 3일때 precision과 recall 구해보기)
trueY = [2, 0, 2, 2, 0, 1]
predY = [0, 0, 2, 2, 0, 2]

# class0:  P=2/3, R=2/2
# class1:   P=0/0, R=0/1
# class2:  P=2/3, R=2/3

result = confusion_matrix(trueY, predY)
result
# Out:
# array([[2, 0, 0],
#        [0, 0, 1],
#        [1, 0, 2]], dtype=int64)

# %%
result = result.transpose()

for i in range(result.shape[0]):
    print('Precision: {0}'.format(result[i, i] / result[i].sum()), 'Recall: {0}'.format(result[i, i] / result[:, i].sum()))
# Out:
# Precision: 0.6666666666666666 Recall: 1.0
# Precision: nan Recall: 0.0
# Precision: 0.6666666666666666 Recall: 0.6666666666666666
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in longlong_scalars
#   after removing the cwd from sys.path.

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(trueY, predY))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.00      0.00      0.00         1
#            2       0.67      0.67      0.67         3
#
#    micro avg       0.67      0.67      0.67         6
#    macro avg       0.44      0.56      0.49         6
# weighted avg       0.56      0.67      0.60         6
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
